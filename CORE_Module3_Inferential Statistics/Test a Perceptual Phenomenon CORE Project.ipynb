# %% [markdown]
# # Project 3 Inferential Statistics - Test a Perceptual Phenomenon - Nitin Ramchand Lalwani

# %% [markdown]
# ## Analyzing the Stroop Task

# %% [markdown]
# The instructions to follow for this project can be found here including the questions to be answered: [Instructions to project](https://docs.google.com/document/u/1/d/1-OkpZLjG_kX9J6LIQ5IltsqMzVWjh36QpnP2RYpVdPU/pub?embedded=True)
#
# Here is a view of the background information of the task:
#
# In a Stroop task, participants are presented with a list of words, with each word displayed in a color of ink. The participant’s task is to say out loud the color of the ink in which the word is printed. The task has two conditions: a congruent words condition, and an incongruent words condition. In the __congruent__ words condition, the words being displayed are color words whose names match the colors in which they are printed: for example RED, BLUE. In the __incongruent__ words condition, the words displayed are color words whose names do not match the colors in which they are printed: for example PURPLE, ORANGE. In each case, we measure the time it takes to name the ink colors in equally-sized lists. Each participant will go through and record a time from each condition.

# %% [markdown]
# __Question__
#
# 1) What is our independent variable? What is our dependent variable?

# %% [markdown]
# __Answer__
#
# The __dependant variable__ in this case is the time taken to name the ink colors.
#
# The __independant variable__ is the color of the ink in which the word is printed.

# %% [markdown]
# __Question__
#
# 2) What is an appropriate set of hypotheses for this task? What kind of statistical test do you expect to perform? Justify your choices.

# %% [markdown]
# __Answer__
#
# The null hypothesis $H_{0}$ for this task is:
#
# $H_0 : \mu_c = \mu_I$ There is __no difference__ between the mean time in indentifying the __congrugent__ words that the mean time in identifying the __incongrugent__ words.
#
# The alternate hypothesis $H_A$ for this task is:
#
# $H_A: \mu_C < \mu_I$. The mean time to identify __incongrugent__ words will take __no longer than__ the mean time taken to identify the __incrogugent__ words.

# %% [markdown]
# __Question__
#
# 3) Report some descriptive statistics regarding this dataset. Include at least one measure of central tendency and at least one measure of variability.

# %% [markdown]
# __Answer__

# %%
import pandas as pd

# %%
df_stroop = pd.read_csv('stroopdata.csv')

# %%
df_stroop.head()
# Out:
#    Congruent  Incongruent
# 0     12.079       19.278
# 1     16.791       18.741
# 2      9.564       21.214
# 3      8.630       15.687
# 4     14.669       22.803

# %%
print "Congruent mean =>", df_stroop['Congruent'].mean(), "Incongruent mean =>", df_stroop['Incongruent'].mean()
# Out:
# Congruent mean => 14.051125 Incongruent mean => 22.0159166667

# %%
print "Congruent median =>", df_stroop['Congruent'].median(), "Incongruent median =>", df_stroop['Incongruent'].median()
# Out:
# Congruent median => 14.3565 Incongruent median => 21.0175

# %%
print "Congruent min =>", round(df_stroop['Congruent'].min(),2), "Incongruent min =>", round(df_stroop['Incongruent'].min(),2)
print "Congruent max =>", round(df_stroop['Congruent'].max(),2), "Incongruent max =>", round(df_stroop['Incongruent'].max(),2)
# Out:
# Congruent min => 8.63 Incongruent min => 15.69
# Congruent max => 22.33 Incongruent max => 35.26

# %%
print "Congruent variance =>", df_stroop['Congruent'].var(), "Incongruent variance =>", df_stroop['Incongruent'].var()
# Out:
# Congruent variance => 12.6690290707 Incongruent variance => 23.0117570362

# %%
print "Congruent standard deviation =>", df_stroop['Congruent'].std(), "Incongruent standard deviation =>", df_stroop['Incongruent'].std()
# Out:
# Congruent standard deviation => 3.55935795765 Incongruent standard deviation => 4.79705712247

# %% [markdown]
# __The mean, median, variance and standard deviation for the congruent words are all lower than the ones for the incongruent words. Furthermore, the min and max value of the congruent words are lower than the ones for the incongruent words.__

# %% [markdown]
# __Question__
#
# 4) Provide one or two visualizations that show the distribution of the sample data. Write one or two sentences noting what you observe about the plot or plots.

# %% [markdown]
# __Answer__

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(color_codes=True)

# %%
fig, ax = plt.subplots(1, 1, figsize = (5, 3), dpi=1000)
sns.distplot(df_stroop['Congruent'],color='purple', bins=8,label='Congruent', kde=False);
sns.distplot(df_stroop['Incongruent'],color='green', bins=8,label='Incongruent', kde=False);
ax.set_title('Histograms of Time taken to identify congruent and incongruent words for a sample of 24');
plt.legend();
ax.set_ylabel('Number of samples');
ax.set_xlabel('Time taken to identify word in seconds');
ax.tick_params(axis='both', which='major', labelsize=6);

# %%
fig, ax = plt.subplots(1, 1, figsize = (5, 3), dpi=1000)
sns.distplot(df_stroop['Congruent'],color='purple', bins=8,label='Congruent');
sns.distplot(df_stroop['Incongruent'],color='green', bins=8,label='Incongruent');
ax.set_title('Histograms of Time taken to identify congruent and incongruent words for a sample of 24');
plt.legend();
ax.set_ylabel('');
ax.set_xlabel('');
ax.tick_params(axis='both', which='major', labelsize=6);
# Out:
# C:\Users\RAMCHAND_N\AppData\Local\Continuum\anaconda3\envs\py27\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# The above plots shows that the distribution of both Congruent and Incongruent words are both categorized as normal distribution. The mean of the incongruent mean is a bit to the right than the congruent mean. Furthermore, the variance of both distrutions looks fairly similar.

# %% [markdown]
# __Question__
#
# 5) Now, perform the statistical test and report your results. What is your confidence level and your critical statistic value? Do you reject the null hypothesis or fail to reject it? Come to a conclusion in terms of the experiment task. Did the results match up with your expectations?

# %% [markdown]
# __Answer__

# %% [markdown]
# There are two types of statistical test that can be conducted. Z-test and T-Test
#
# Z-test are useful when we know the population parameters $\mu$ and $\sigma$.
#
# However for this data we have collected in the stroopdata.csv we just have a sample of 24 that we are looking at.
#
# When performing the statistical test, we use the dependant T-test. The reason is that in this case the same subject/person is asked to identify Congruent and Incongruent words and in fact it makes sense when comparing that it is the same person doing so. This results in two values one for congruent words and one for incongruent words.

# %% [markdown]
# For performing the ttest for dependant samples on python we use scipy.stats.ttest_rel to check whether the two samples have identical average values and therefore be able to reject or not the null hypothesis.

# %%
from scipy import stats

# %%
stats.ttest_rel(df_stroop['Congruent'], df_stroop['Incongruent'])
# Out:
# Ttest_relResult(statistic=-8.020706944109957, pvalue=4.103000585711178e-08)

# %% [markdown]
# Here since the p value results obtainted is much smaller than 5% (0.05) threshold, __we can reject the null hypothesis__. This 5% benchmark is the one used in most papers and examples but however for this test it is also less than 1% so in all cases can be reject the null hypothesis. This 5% or 1% threshold, is known as the __Type I error__ which is when the null hypothesis is true but it is rejected. It is like a false positive.

# %% [markdown]
# The result of rejecting the null hypothesis makes sense compared to what is intuitive. It makes sense it doesn't take subjects the same time in average to identify Incongruent words than congruent words.
