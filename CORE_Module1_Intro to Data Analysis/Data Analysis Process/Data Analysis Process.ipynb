# %%
import unicodecsv


def read_csv(filename):
    with open(filename, 'rb') as f:
        reader = unicodecsv.DictReader(f)
        return list(reader)

enrollments = read_csv('C:\Users\RAMCHAND_N\OneDrive - Airbus\CDF work - NEW\Jupyter Workspaces\Data Analysis Nanodegree\Data Analysis Process\enrollments.csv')
project_submissions = read_csv('C:\Users\RAMCHAND_N\OneDrive - Airbus\CDF work - NEW\Jupyter Workspaces\Data Analysis Nanodegree\Data Analysis Process\project_submissions.csv')
daily_engagement = read_csv('C:\Users\RAMCHAND_N\OneDrive - Airbus\CDF work - NEW\Jupyter Workspaces\Data Analysis Nanodegree\Data Analysis Process\daily_engagement.csv')
    
print 'enrollments=' ,enrollments[0]
print 'daily_engagement=' ,daily_engagement[0]
print 'project_submissions=' ,project_submissions[0]
# Out:
# enrollments= {u'status': u'canceled', u'is_udacity': u'True', u'is_canceled': u'True', u'join_date': u'2014-11-10', u'account_key': u'448', u'cancel_date': u'2015-01-14', u'days_to_cancel': u'65'}
# daily_engagement= {u'lessons_completed': u'0.0', u'num_courses_visited': u'1.0', u'total_minutes_visited': u'11.6793745', u'projects_completed': u'0.0', u'acct': u'0', u'utc_date': u'2015-01-09'}
# project_submissions= {u'lesson_key': u'3176718735', u'processing_state': u'EVALUATED', u'account_key': u'256', u'assigned_rating': u'UNGRADED', u'completion_date': u'2015-01-16', u'creation_date': u'2015-01-14'}

# %%
   
with open(daily_engagement, 'rb') as d_e_file:
    reader = unicodecsv.reader(d_e_file)
    print row1[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-f4dc8515b63d> in <module>()
#       1
# ----> 2 with open(daily_engagement, 'rb') as d_e_file:
#       3  reader = unicodecsv.reader(d_e_file)
#       4  print row1[0]
#
# TypeError: coercing to Unicode: need string or buffer, list found

# %%
with open(daily_engagement, 'rb') as d_e_file:
    reader = unicodecsv.DictReader(d_e_file)
    for row in range(2):
        print reader.next()
project_submissions = None  # Replace this with your code
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-d45e6dd03c67> in <module>()
# ----> 1 with open(daily_engagement, 'rb') as d_e_file:
#       2     reader = unicodecsv.DictReader(d_e_file)
#       3     for row in range(2):
#       4         print reader.next()
#       5 project_submissions = None  # Replace this with your code
#
# TypeError: coercing to Unicode: need string or buffer, list found

# %%
from datetime import datetime as dt

# Takes a date as a string, and returns a Python datetime object. 
# If there is no date given, returns None
def parse_date(date):
    if date == '':
        return None
    else:
        return dt.strptime(date, '%Y-%m-%d')
    
# Takes a string which is either an empty string or represents an integer,
# and returns an int or None.
def parse_maybe_int(i):
    if i == '':
        return None
    else:
        return int(i)

# Clean up the data types in the enrollments table
for enrollment in enrollments:
    enrollment['cancel_date'] = parse_date(enrollment['cancel_date'])
    enrollment['days_to_cancel'] = parse_maybe_int(enrollment['days_to_cancel'])
    enrollment['is_canceled'] = enrollment['is_canceled'] == 'True'
    enrollment['is_udacity'] = enrollment['is_udacity'] == 'True'
    enrollment['join_date'] = parse_date(enrollment['join_date'])
#    enrollment['account_key'] = parse_maybe_int(enrollment['account_key'])

# %%
list(set([x[0] for x in enrollments.values()]))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-fa9f55c85032> in <module>()
# ----> 1 list(set([x[0] for x in enrollments.values()]))
#
# AttributeError: 'list' object has no attribute 'values'

# %%
row_count_e = sum(1 for row in enrollments)
print row_count_e
# Out:
# 1640

# %%
row_count_d = sum(1 for row in daily_engagement)
print row_count_d
# Out:
# 136240

# %%
row_count_p = sum(1 for row in project_submissions)
print row_count_p

# %%
import pandas as pd

pandas_enrollments= pd.DataFrame(data=enrollments)

# %%
pandas_enrollments
# Out:
#       account_key cancel_date  days_to_cancel  is_canceled  is_udacity  \
# 0             448  2015-01-14            65.0         True        True
# 1             448  2014-11-10             5.0         True        True
# 2             448  2015-01-27             0.0         True        True
# 3             448  2014-11-10             0.0         True        True
# 4             448         NaT             NaN        False        True
# 5             448  2015-01-27            13.0         True        True
# 6             448  2015-03-10            42.0         True        True
# 7             448  2015-01-27             0.0         True        True
# 8             448  2015-01-27             0.0         True        True
# 9             700  2014-11-16             6.0         True       False
# 10            429  2015-03-10           120.0         True       False
# 11            429  2015-06-17            99.0         True       False
# ...

# %%
pandas_enrollments['account_key'].nunique()
# Out:
# 1302

# %%
enrollments[0]
# Out:
# {u'account_key': u'448',
#  u'cancel_date': datetime.datetime(2015, 1, 14, 0, 0),
#  u'days_to_cancel': 65,
#  u'is_canceled': True,
#  u'is_udacity': True,
#  u'join_date': datetime.datetime(2014, 11, 10, 0, 0),
#  u'status': u'canceled'}

# %%
len(unique_project_submitters)
# Out:
# 743

# %%
for engagement_record in daily_engagement:
    engagement_record['account_key'] = engagement_record['acct']
    del engagement_record['acct']

# %%
enrollments[0:2]
# Out:
# [{u'account_key': u'448',
#   u'cancel_date': datetime.datetime(2015, 1, 14, 0, 0),
#   u'days_to_cancel': 65,
#   u'is_canceled': True,
#   u'is_udacity': True,
#   u'join_date': datetime.datetime(2014, 11, 10, 0, 0),
#   u'status': u'canceled'},
#  {u'account_key': u'448',
#   u'cancel_date': datetime.datetime(2014, 11, 10, 0, 0),
#   u'days_to_cancel': 5,
#   u'is_canceled': True,
#   u'is_udacity': True,
#   u'join_date': datetime.datetime(2014, 11, 5, 0, 0),
#   u'status': u'canceled'}]

# %%
def get_unique_students(data):
    unique_students = set()
    for data_point in data:
        unique_students.add(data_point['account_key'])
    return unique_students

# %%
unique_engagement_students = get_unique_students(daily_engagement)


daily_engagement[0]['account_key']
# Out:
# u'0'

# %%
unique_enrolled_students = get_unique_students(enrollments)




unique_project_submitters = get_unique_students(project_submissions)

# %%
unique_engagement_students[2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-82-9abb2acdfc1b> in <module>()
# ----> 1 unique_engagement_students[2]
#
# TypeError: 'set' object does not support indexing

# %%
#for enrollment in enrollments:
#    enrollment['account_key'] = parse_maybe_int(enrollment['account_key'])

missing_de = unique_enrolled_students.difference(unique_engagement_students)

print missing_de
print len(missing_de)
# Out:
# set([u'1304', u'1129', u'1186', u'875', u'1222', u'1213', u'1120', u'749', u'1148', u'707', u'766', u'1125', u'1237', u'870', u'878', u'819', u'1191', u'1190', u'1145', u'733', u'799', u'871', u'717', u'654', u'727', u'737', u'739', u'914', u'1219', u'1291', u'1010', u'889', u'817', u'1025', u'997', u'996', u'981', u'1171', u'1270', u'1218', u'1273', u'1238', u'902', u'711', u'750', u'664', u'1069', u'1284', u'841', u'1044', u'1086', u'1155', u'1079', u'968', u'789', u'1241', u'964', u'725', u'884', u'728', u'1101', u'803', u'802', u'1063', u'926'])
# 65

# %%
daily_engagement[0]
# Out:
# {'account_key': u'0',
#  u'lessons_completed': u'0.0',
#  u'num_courses_visited': u'1.0',
#  u'projects_completed': u'0.0',
#  u'total_minutes_visited': u'11.6793745',
#  u'utc_date': u'2015-01-09'}

# %%
test = enrollments[2]

# %%
test['account_key']
# Out:
# u'448'

# %%
'1219' in missing_de
# Out:
# True

# %%
for enrollment in enrollments:
    student = enrollment['account_key']
    zero_days_enrollment = enrollment['days_to_cancel']
    if student not in unique_engagement_students and zero_days_enrollment !=0:
        print enrollment
# Out:
# {u'status': u'canceled', u'is_udacity': True, u'is_canceled': True, u'join_date': datetime.datetime(2015, 1, 10, 0, 0), u'account_key': u'1304', u'cancel_date': datetime.datetime(2015, 3, 10, 0, 0), u'days_to_cancel': 59}
# {u'status': u'canceled', u'is_udacity': True, u'is_canceled': True, u'join_date': datetime.datetime(2015, 3, 10, 0, 0), u'account_key': u'1304', u'cancel_date': datetime.datetime(2015, 6, 17, 0, 0), u'days_to_cancel': 99}
# {u'status': u'current', u'is_udacity': True, u'is_canceled': False, u'join_date': datetime.datetime(2015, 2, 25, 0, 0), u'account_key': u'1101', u'cancel_date': None, u'days_to_cancel': None}

# %%
for enrollment in enrollments:
    if enrollment['account_key'] == '1101' or enrollment['account_key'] == '1304':
        print enrollment
# Out:
# {u'status': u'canceled', u'is_udacity': True, u'is_canceled': True, u'join_date': datetime.datetime(2015, 1, 10, 0, 0), u'account_key': u'1304', u'cancel_date': datetime.datetime(2015, 3, 10, 0, 0), u'days_to_cancel': 59}
# {u'status': u'canceled', u'is_udacity': True, u'is_canceled': True, u'join_date': datetime.datetime(2015, 3, 10, 0, 0), u'account_key': u'1304', u'cancel_date': datetime.datetime(2015, 6, 17, 0, 0), u'days_to_cancel': 99}
# {u'status': u'current', u'is_udacity': True, u'is_canceled': False, u'join_date': datetime.datetime(2015, 2, 25, 0, 0), u'account_key': u'1101', u'cancel_date': None, u'days_to_cancel': None}

# %%
paid_students = {}
for enrollment in enrollments:
    if enrollment['days_to_cancel'] is None or enrollment['days_to_cancel']>7:
        paid_students[enrollment['account_key']] = enrollment['join_date']
print len(paid_students)
# Out:
# 999

# %%
enrollments[0:2]
# Out:
# [{u'account_key': u'448',
#   u'cancel_date': datetime.datetime(2015, 1, 14, 0, 0),
#   u'days_to_cancel': 65,
#   u'is_canceled': True,
#   u'is_udacity': True,
#   u'join_date': datetime.datetime(2014, 11, 10, 0, 0),
#   u'status': u'canceled'},
#  {u'account_key': u'448',
#   u'cancel_date': datetime.datetime(2014, 11, 10, 0, 0),
#   u'days_to_cancel': 5,
#   u'is_canceled': True,
#   u'is_udacity': True,
#   u'join_date': datetime.datetime(2014, 11, 5, 0, 0),
#   u'status': u'canceled'}]
