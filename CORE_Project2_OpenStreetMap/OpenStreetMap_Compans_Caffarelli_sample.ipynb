# %% [markdown]
# # Project Nitin Ramchand Data Wrangling with MongoDB

# %% [markdown]
# ## Wrangle OpenStreetMap Data for Toulouse region

# %% [markdown]
# The region of Toulouse for which the OpenStreetMap Data is wrangled is the one shown in the orange perimeter in the below image.

# %% [markdown]
# Import all the libraries

# %%
import os
import os.path
import sys
import time
import requests
import xml.etree.cElementTree as ET
from pprint import pprint
import re
import codecs
import json
from collections import defaultdict
import bson
import pymongo
import matplotlib.pyplot as plt

# %% [markdown]
# ## Auditing the OpenStreetMap Data (OSM XML File) for neighbourhood of Compans Caffarelli which is in the area of Toulouse

# %% [markdown]
# The following function __count_tags()__ counts the number of different tags that there are in the osm file  and stores them in a dictionary. It uses the iterparse mehtod to process the map file to get a feeling of what tags the input file has and how many there are of each. Using this iterparse method makes sense when processing such a big osm file.

# %%
def count_tags(filename):
    count_tag_dict = {}
    for event, elem in ET.iterparse(filename):
        if elem.tag not in count_tag_dict:
            count_tag_dict[elem.tag] = 1
        else:
            count_tag_dict[elem.tag] += 1
    return count_tag_dict

# %%
tags = count_tags('Compans_Caffarelli.osm')
pprint(tags)
# Out:
# {'bounds': 1,
#  'member': 5958,
#  'meta': 1,
#  'nd': 24310,
#  'node': 16466,
#  'note': 1,
#  'osm': 1,
#  'relation': 217,
#  'tag': 16265,
#  'way': 2533}

# %% [markdown]
# As we can see, there are several tags, namely __bounds, meta, note and osm__, which occur once are the ones that contain the meta data of the osm file. <br>
# <br>
# The rest of the tags are the ones that we will look in detail and try and clean and so on. <br>
# <br>
# Nodes, Ways and Relations are known as elements in Open Street Map compising a osm file. <br>
# - __Nodes:__ (defining points in space),<br>
# - __Ways:__ (defining linear features and area boundaries), and <br>
# - __Relations:__ (which are sometimes used to explain how other elements work together).
# <br>
# <br>
# All above mentioned elements contain a child tag called tag.<br>
# - __Tag:__ All types of data element (nodes, ways and relations), as well as changesets, can have tags. It is a child tag inside an element which describes the meaning of the particular element to which they are attached. A tag consists of two free format text fields; a 'key' and a 'value'.
#
# Finally the last two tags found in the osm file are member and nd.<br>
# - __Member:__ is a child tag under relation and is used to define logical or geographic relationships between other elements. A member of a relation can optionally have a role which describes the part that a particular feature plays within a relation.
#
# - __nd:__ is also a chiled tag in this case under the element way which gives more detail of what are the node references for a specific way.

# %% [markdown]
# Giving an example of how the OSM XML file looks:
#
# A Node element looks like the following:
#
# ```XML
# <node id="4250506436" lat="43.6119336" lon="1.4383687" version="3" timestamp="2017-09-24T09:18:10Z" changeset="52323529" uid="2774341" user="Floeditor">
#     <tag k="addr:city" v="Toulouse"/>
#     <tag k="addr:housenumber" v="15"/>
#     <tag k="addr:postcode" v="31000"/>
#     <tag k="addr:street" v="Avenue Honoré Serres"/>
#     <tag k="amenity" v="restaurant"/>
#     <tag k="name" v="Fiel mon restô"/>
#     <tag k="phone" v="+33 5 61 21 82 72"/>
#     <tag k="source" v="survey"/>
#     <tag k="website" v="http://fielmonresto.com/"/>
#   </node>
# ```
#
# A way element looks like the following:
# ```XML
#   <way id="64649549" version="2" timestamp="2012-12-19T15:17:01Z" changeset="14332349" uid="297482" user="don-vip">
#     <nd ref="793922896"/>
#     <nd ref="1536844827"/>
#     <nd ref="793925492"/>
#     <nd ref="793918685"/>
#     <nd ref="793923221"/>
#     <nd ref="793928395"/>
#     <nd ref="793922896"/>
#     <tag k="building" v="yes"/>
#     <tag k="source" v="cadastre-dgi-fr source : Direction Générale des Impôts - Cadastre. Mise à jour : 2010"/>
#   </way>
# ```
#
#  A relation element looks like the following:
# ```XML
#    <relation id="1546842" version="1" timestamp="2011-04-17T21:24:48Z" changeset="7892211" uid="297482" user="don-vip">
#     <member type="node" ref="1249091595" role="stop"/>
#     <member type="node" ref="1249091584" role="stop"/>
#     <member type="node" ref="1249091573" role="stop"/>
#     <member type="node" ref="1045297714" role="platform"/>
#     <member type="node" ref="1148214269" role="platform"/>
#     <member type="node" ref="1148214274" role="platform"/>
#     <tag k="name" v="Héraclès"/>
#     <tag k="public_transport" v="stop_area"/>
#     <tag k="type" v="public_transport"/>
#   </relation>
# ```

# %% [markdown]
# Before importing the Open Street Map XML file to a database to perform some statistical analysis on what is contained inside the Toulouse region, we want to clean up the data inside teh OSM XML file. Once cleaned then we want to convert it to a JSON file so that then we can import it in a MongoDB database to perform our queries.
#
# The format in which we want to convert the OSM XML file is the following:
#
# ```
# {
# "id": "2406124091",
# "type: "node",
# "visible":"true",
# "created": {
#           "version":"2",
#           "changeset":"17206049",
#           "timestamp":"2013-08-03T16:43:42Z",
#           "user":"linuxUser16",
#           "uid":"1219059"
#         },
# "pos": [41.9757030, -87.6921867],
# "address": {
#           "housenumber": "5157",
#           "postcode": "60625",
#           "street": "North Lincoln Ave"
#         },
# "amenity": "restaurant",
# "cuisine": "mexican",
# "name": "La Cabana De Don Luis",
# "phone": "1 (773)-271-5176"
# }
# ```

# %% [markdown]
# Next, to get familiar with the types of attributes for each tag, we look at how many of each attribute for each tag exist. The following function __count_attributes()__ is the one that defines a dcitionary that counts the number of sttributes types.

# %%
def count_attributes(filename):
    count_attributes_dict = {}
    for _, element in ET.iterparse(filename):
        for attribute in element.attrib:
            if attribute not in count_attributes_dict:
                count_attributes_dict[attribute] = 1
            else:
                count_attributes_dict[attribute] += 1
    return count_attributes_dict               
   

attributes = count_attributes('Compans_Caffarelli.osm')
pprint(attributes)
# Out:
# {'changeset': 19216,
#  'generator': 1,
#  'id': 19216,
#  'k': 16265,
#  'lat': 16466,
#  'lon': 16466,
#  'maxlat': 1,
#  'maxlon': 1,
#  'minlat': 1,
#  'minlon': 1,
#  'osm_base': 1,
#  'ref': 30268,
#  'role': 5958,
#  'timestamp': 19216,
#  'type': 5958,
#  'uid': 19216,
#  'user': 19216,
#  'v': 16265,
#  'version': 19217}

# %% [markdown]
# As we can see above, aside from the attributes found in each of the elements (node, way, and relation) and some of the meta data attributes which are found only once, the k and the v attributes are very interesting since they are under the tag "tag" of most elements. The k attribute represents the key and the v the value of that key.
#
# It is worth diggining deeper into what type of keys are there since we can observe that in the file there are many different types of key values which we can clean up before passing them into the JSON format mentioned above. The following __types_keys()__ function ouputs a dictionary showing the key "k" attributes under alls tags named "tag" and how many times do they show up. The dictionary types_keys_dict has all 'k' values sotred with the occurences and the dictionary that is shown below is keys_slice_dict which shows the 'k' attributes that occur more than 100 times in the OpenStreetMap OSM XML file.

# %%
def types_keys(filename):
    types_keys_dict = {}
    for event, element in ET.iterparse(filename, events=("start","end")):
        if event == "start":
            for tag in element.iter("tag"):
                key = tag.attrib['k']
                if key not in types_keys_dict:
                    types_keys_dict[key] = 1
                else:
                    types_keys_dict[key] += 1
    return types_keys_dict               
   

types_keys_dict = types_keys('Toulouse.osm')
keys_slice_dict = dict((k, v) for k, v in types_keys_dict.items() if v >= 20)
pprint(keys_slice_dict)
# Out:
# {'CEMT': 68,
#  'CLC:code': 52,
#  'CLC:id': 54,
#  'CLC:year': 54,
#  'FIXME': 66,
#  'access': 29778,
#  'access:disabled': 35,
#  'addr:city': 13529,
#  'addr:country': 9667,
#  'addr:housename': 349,
#  'addr:housenumber': 165574,
#  'addr:place': 26,
#  'addr:postcode': 7522,
#  'addr:street': 32283,
#  'addr:unit': 34,
#  'admin_level': 770,
#  'advertising': 3496,
#  'advertising:animated': 22,
#  'advertising:luminous': 22,
#  'advertising:size': 22,
#  'aeroway': 1381,
#  'air_conditioning': 206,
#  'alt_name': 617,
#  'amenity': 31293,
#  'animated': 30,
#  'area': 918,
#  'artist_name': 81,
#  'artwork_type': 103,
#  'atm': 547,
#  'attraction': 93,
#  'backrest': 1286,
#  'barrier': 15115,
#  'bench': 2386,
#  'bicycle': 12571,
#  'bicycle_parking': 614,
#  'bike_safety': 112,
#  'bin': 643,
#  'board_type': 34,
#  'boat': 332,
#  'bollard': 119,
#  'border_type': 36,
#  'boules': 76,
#  'boundary': 1353,
#  'brand': 922,
#  'brand:website': 62,
#  'brand:wikidata': 700,
#  'brand:wikipedia': 628,
#  'brewery': 54,
#  'bridge': 2159,
#  'bridge:name': 72,
#  'building': 735207,
#  'building:colour': 67,
#  'building:facade:material': 87,
#  'building:levels': 5519,
#  'building:levels:underground': 29,
#  'building:material': 171,
#  'building:min_level': 105,
#  'building:part': 698,
#  'building:shape': 43,
#  'bulk_purchase': 71,
#  'bus': 9050,
#  'bus_bay': 70,
#  'busway': 149,
#  'busway:left': 42,
#  'busway:right': 235,
#  'button_operated': 102,
#  'by_night': 36,
#  'cables': 288,
#  'camera:direction': 130,
#  'camera:mount': 354,
#  'camera:type': 309,
#  'capacity': 2863,
#  'capacity:disabled': 1331,
#  'change:lanes': 41,
#  'change:lanes:backward': 20,
#  'change:lanes:forward': 20,
#  'change_machine': 38,
#  'charge': 26,
#  'circuits': 26,
#  'clothes': 502,
#  'collection_times': 120,
#  'colour': 1804,
#  'colour:arrow': 40,
#  'colour:back': 58,
#  'colour:text': 58,
#  'communication:mobile_phone': 66,
#  'community': 28,
#  'community_centre:for': 21,
#  'compressed_air': 84,
#  'confectionery': 34,
#  'construction': 119,
#  'contact:addr': 34,
#  'contact:city': 74,
#  'contact:email': 76,
#  'contact:facebook': 127,
#  'contact:fax': 165,
#  'contact:google_plus': 22,
#  'contact:housenumber': 124,
#  'contact:phone': 778,
#  'contact:postcode': 76,
#  'contact:street': 124,
#  'contact:twitter': 22,
#  'contact:website': 336,
#  'conveying': 67,
#  'copy_facility': 63,
#  'covered': 3140,
#  'craft': 134,
#  'created_by': 6806,
#  'crossing': 8856,
#  'crossing:barrier': 317,
#  'crossing:island': 120,
#  'crossing:light': 36,
#  'crossing_ref': 6846,
#  'cuisine': 1754,
#  'currency:EUR': 24,
#  'currency:XLT': 44,
#  'cutting': 122,
#  'cycleway': 3958,
#  'cycleway:both': 102,
#  'cycleway:left': 425,
#  'cycleway:right': 546,
#  'dance:style': 42,
#  'dance:teaching': 26,
#  'defibrillator:location': 163,
#  'delivery': 115,
#  'demolished': 48,
#  'demolished:building': 485,
#  'demolished:highway': 28,
#  'denomination': 290,
#  'denotation': 22,
#  'departures_board': 50,
#  'description': 2295,
#  'destination': 378,
#  'destination:lanes': 112,
#  'destination:ref': 36,
#  'destroyed:building': 54,
#  'diet:halal': 22,
#  'diet:vegan': 59,
#  'diet:vegetarian': 107,
#  'direction': 2182,
#  'disabled': 56,
#  'dispensing': 536,
#  'display_surface': 30,
#  'distance': 127,
#  'disused:boundary': 24,
#  'disused:shop': 54,
#  'drinking_water': 22,
#  'drive_through': 87,
#  'ele': 717,
#  'electrified': 932,
#  'email': 276,
#  'embankment': 52,
#  'emergency': 3189,
#  'end_date': 72,
#  'enforcement': 54,
#  'entrance': 1854,
#  'exit_to': 59,
#  'facebook': 32,
#  'fax': 53,
#  'fee': 881,
#  'fence_type': 140,
#  'fire_hydrant:position': 1535,
#  'fire_hydrant:type': 2273,
#  'fitness_station': 34,
#  'fixme': 485,
#  'fixme:tags': 26,
#  'foot': 9601,
#  'footway': 3700,
#  'ford': 22,
#  'frequency': 628,
#  'from': 463,
#  'fuel:diesel': 168,
#  'fuel:e10': 146,
#  'fuel:e85': 32,
#  'fuel:lpg': 32,
#  'fuel:octane_95': 80,
#  'fuel:octane_98': 137,
#  'gantry:type': 67,
#  'gauge': 1442,
#  'generator:method': 64,
#  'generator:output:electricity': 30,
#  'generator:source': 72,
#  'generator:type': 24,
#  'genus': 128,
#  'golf': 1243,
#  'handicap': 36,
#  'handrail': 75,
#  'handrail:left': 28,
#  'healthcare': 209,
#  'healthcare:speciality': 124,
#  'height': 1619,
#  'heritage': 433,
#  'heritage:operator': 435,
#  'hgv': 226,
#  'hgv:lanes': 48,
#  'highway': 156701,
#  'hiking': 237,
#  'historic': 431,
#  'history': 78,
#  'horse': 497,
#  'icao': 24,
#  'image': 1261,
#  'importance': 577,
#  'incline': 701,
#  'indoor': 371,
#  'information': 550,
#  'inscription': 24,
#  'int_ref': 466,
#  'intermittent': 181,
#  'internet_access': 150,
#  'internet_access:fee': 63,
#  'is_in': 58,
#  'junction': 4058,
#  'kerb': 194,
#  'lamp_type': 70,
#  'land_property': 30,
#  'landuse': 6920,
#  'lanes': 6166,
#  'lanes:backward': 183,
#  'lanes:forward': 190,
#  'layer': 4470,
#  'leaf_cycle': 319,
#  'leaf_type': 1547,
#  'legal_type:FR': 30,
#  'leisure': 22431,
#  'length': 20,
#  'level': 1794,
#  'lift_gate:type': 32,
#  'line': 197,
#  'lit': 2855,
#  'location': 2297,
#  'location:transition': 22,
#  'luminous': 30,
#  'man_made': 2367,
#  'manhole': 36,
#  'map_size': 74,
#  'map_type': 78,
#  'mapillary': 3239,
#  'material': 1022,
#  'max_age': 31,
#  'maxheight': 469,
#  'maxspeed': 15899,
#  'maxspeed:conditional': 196,
#  'maxspeed:lanes': 24,
#  'maxspeed:type': 1007,
#  'maxstay': 54,
#  'maxweight': 254,
#  'memorial': 36,
#  'message': 65,
#  'message:front': 24,
#  'message:opposite': 24,
#  'mhs:inscription_date': 182,
#  'milestone': 20,
#  'min_age': 47,
#  'min_height': 157,
#  'motor_vehicle': 1068,
#  'motorboat': 55,
#  'motorcar': 233,
#  'motorcycle': 231,
#  'motorcycle_parking': 23,
#  'mtb': 92,
#  'mtb:scale': 91,
#  'mtb:scale:uphill': 20,
#  'name': 93895,
#  'name:am': 23,
#  'name:ar': 26,
#  'name:az': 26,
#  'name:be': 26,
#  'name:bg': 30,
#  'name:bo': 24,
#  'name:br': 26,
#  'name:ca': 34,
#  'name:ce': 24,
#  'name:co': 23,
#  'name:csb': 23,
#  'name:el': 38,
#  'name:en': 74,
#  'name:eo': 25,
#  'name:es': 47,
#  'name:etymology:wikidata': 137,
#  'name:eu': 24,
#  'name:fa': 33,
#  'name:fr': 287,
#  'name:frp': 24,
#  'name:gl': 24,
#  'name:he': 23,
#  'name:hi': 22,
#  'name:hy': 24,
#  'name:it': 26,
#  'name:ja': 34,
#  'name:ka': 25,
#  'name:kk': 23,
#  'name:kn': 22,
#  'name:ko': 25,
#  'name:la': 34,
#  'name:lt': 26,
#  'name:lv': 24,
#  'name:mhr': 22,
#  'name:ml': 22,
#  'name:mr': 24,
#  'name:mzn': 31,
#  'name:nap': 22,
#  'name:oc': 2978,
#  'name:os': 23,
#  'name:pa': 23,
#  'name:pl': 27,
#  'name:pms': 24,
#  'name:pnb': 24,
#  'name:ru': 40,
#  'name:sc': 22,
#  'name:scn': 23,
#  'name:sr': 34,
#  'name:ta': 22,
#  'name:th': 24,
#  'name:tt': 22,
#  'name:uk': 38,
#  'name:ur': 22,
#  'name:vec': 24,
#  'name:wikipedia': 31,
#  'name:xmf': 23,
#  'name:yi': 22,
#  'name:yue': 22,
#  'name:zh': 38,
#  'natural': 20820,
#  'network': 2161,
#  'noexit': 469,
#  'noname': 303,
#  'note': 1653,
#  'office': 1450,
#  'official_name': 152,
#  'old_name': 212,
#  'old_operator': 34,
#  'old_ref': 612,
#  'oneway': 25622,
#  'oneway:bicycle': 135,
#  'oneway:bus': 22,
#  'opening_hours': 2947,
#  'operator': 23482,
#  'operator:type': 602,
#  'operator:wikidata': 59,
#  'organic': 128,
#  'orientation': 30,
#  'outdoor_seating': 427,
#  'owner': 24,
#  'par': 80,
#  'park_ride': 94,
#  'parking': 2737,
#  'parking:condition:both': 140,
#  'parking:condition:both:2': 134,
#  'parking:condition:both:2:fee_per_hour': 132,
#  'parking:condition:both:2:maxstay': 133,
#  'parking:condition:both:2:time_interval': 133,
#  'parking:condition:both:3': 133,
#  'parking:condition:both:3:maxstay': 108,
#  'parking:condition:both:3:residents': 132,
#  'parking:condition:both:3:time_interval': 25,
#  'parking:condition:both:default': 131,
#  'parking:condition:both:fee_per_hour': 131,
#  'parking:condition:both:maxstay': 131,
#  'parking:condition:both:time_interval': 131,
#  'parking:condition:left': 137,
#  'parking:condition:left:2': 135,
#  'parking:condition:left:2:fee_per_hour': 135,
#  'parking:condition:left:2:maxstay': 135,
#  'parking:condition:left:2:time_interval': 135,
#  'parking:condition:left:3': 135,
#  'parking:condition:left:3:maxstay': 102,
#  'parking:condition:left:3:residents': 133,
#  'parking:condition:left:3:time_interval': 32,
#  'parking:condition:left:default': 136,
#  'parking:condition:left:fee_per_hour': 133,
#  'parking:condition:left:maxstay': 133,
#  'parking:condition:left:time_interval': 133,
#  'parking:condition:right': 173,
#  'parking:condition:right:2': 171,
#  'parking:condition:right:2:fee_per_hour': 169,
#  'parking:condition:right:2:maxstay': 169,
#  'parking:condition:right:2:time_interval': 169,
#  'parking:condition:right:3': 169,
#  'parking:condition:right:3:maxstay': 145,
#  'parking:condition:right:3:residents': 167,
#  'parking:condition:right:3:time_interval': 23,
#  'parking:condition:right:default': 176,
#  'parking:condition:right:fee_per_hour': 166,
#  'parking:condition:right:maxstay': 170,
#  'parking:condition:right:time_interval': 165,
#  'parking:lane:both': 1149,
#  'parking:lane:both:capacity': 122,
#  'parking:lane:both:parallel': 126,
#  'parking:lane:left': 359,
#  'parking:lane:left:capacity': 148,
#  'parking:lane:left:parallel': 136,
#  'parking:lane:right': 387,
#  'parking:lane:right:capacity': 187,
#  'parking:lane:right:parallel': 185,
#  'parking_lane': 2659,
#  'parking_space': 275,
#  'passenger_information_display': 83,
#  'passenger_lines': 511,
#  'payment:cash': 69,
#  'payment:cash:XLT-SVLT': 41,
#  'payment:coins': 28,
#  'payment:credit_cards': 77,
#  'payment:mastercard': 37,
#  'payment:visa': 47,
#  'permanent': 55,
#  'phone': 2176,
#  'place': 623,
#  'placement': 256,
#  'planned:ref': 40,
#  'playground': 94,
#  'pole': 459,
#  'police:FR': 59,
#  'political_division': 583,
#  'population': 102,
#  'post_box:type': 491,
#  'power': 10689,
#  'psv': 1222,
#  'public_transport': 9567,
#  'public_transport:version': 509,
#  'railway': 3336,
#  'ramp': 76,
#  'ramp:bicycle': 31,
#  'ramp:wheelchair': 46,
#  'recycling:batteries': 26,
#  'recycling:cans': 425,
#  'recycling:cardboard': 377,
#  'recycling:cartons': 20,
#  'recycling:clothes': 576,
#  'recycling:electrical_appliances': 24,
#  'recycling:glass': 2441,
#  'recycling:glass_bottles': 2569,
#  'recycling:green_waste': 26,
#  'recycling:magazines': 30,
#  'recycling:newspaper': 34,
#  'recycling:paper': 441,
#  'recycling:paper_packaging': 21,
#  'recycling:plastic': 46,
#  'recycling:plastic_bottles': 388,
#  'recycling:plastic_packaging': 65,
#  'recycling:scrap_metal': 21,
#  'recycling:waste': 103,
#  'recycling_type': 2877,
#  'ref': 20800,
#  'ref:FR:CEF': 148,
#  'ref:FR:CNC': 24,
#  'ref:FR:FANTOIR': 7114,
#  'ref:FR:FINESS': 591,
#  'ref:FR:GendarmerieNationale': 25,
#  'ref:FR:LaPoste': 127,
#  'ref:FR:NAF': 32,
#  'ref:FR:RTE': 62,
#  'ref:FR:RTE_nom': 56,
#  'ref:FR:SIREN': 98,
#  'ref:FR:SIRET': 26,
#  'ref:FR:ToulouseMetropole': 250,
#  'ref:FR:aec31': 197,
#  'ref:FR:prix-carburants': 165,
#  'ref:FR:uic8': 105,
#  'ref:INSEE': 243,
#  'ref:UAI': 979,
#  'ref:grandtoulouse': 72,
#  'ref:mhs': 434,
#  'ref:sandre': 161,
#  'religion': 348,
#  'residential': 50,
#  'residents': 20,
#  'restriction': 608,
#  'roof:colour': 174,
#  'roof:direction': 20,
#  'roof:height': 143,
#  'roof:levels': 388,
#  'roof:material': 329,
#  'roof:orientation': 132,
#  'roof:orientation:compass': 58,
#  'roof:shape': 5016,
#  'rooms': 21,
#  'route': 613,
#  'route_master': 250,
#  'route_ref': 141,
#  'sac_scale': 66,
#  'school:FR': 994,
#  'seamark:gate:category': 20,
#  'seamark:type': 34,
#  'seats': 708,
#  'second_hand': 40,
#  'segregated': 2700,
#  'self_service': 28,
#  'service': 19336,
#  'service:bicycle:repair': 22,
#  'service_times': 24,
#  'shelter': 4294,
#  'shelter_type': 107,
#  'shop': 7955,
#  'short_name': 1097,
#  'short_name:ca': 22,
#  'short_name:eu': 22,
#  'shoulder': 37,
#  'shoulder:right': 321,
#  'sides': 30,
#  'sidewalk': 281,
#  'site': 199,
#  'size': 30,
#  'ski': 21,
#  'sloped_curb': 38,
#  'smoking': 144,
#  'smoothness': 364,
#  'snowmobile': 21,
#  'social_facility': 72,
#  'social_facility:for': 60,
#  'source': 1017190,
#  'source:addr:postcode': 108,
#  'source:date': 116988,
#  'source:date:ref:aec31': 197,
#  'source:geometry': 77,
#  'source:heritage': 132,
#  'source:location': 43,
#  'source:maxspeed': 2236,
#  'source:maxweight': 56,
#  'source:name': 187,
#  'source:name:oc': 1467,
#  'source:outline': 26,
#  'source:population': 100,
#  'source:ref:aec31': 193,
#  'source:url': 47,
#  'species': 62,
#  'sport': 3312,
#  'stamping_machine': 93,
#  'stars': 130,
#  'start_date': 417,
#  'station': 74,
#  'step_count': 104,
#  'sti': 1597,
#  'street_cabinet': 144,
#  'substance': 35,
#  'substation': 5410,
#  'subway': 78,
#  'supervised': 219,
#  'surface': 25116,
#  'surveillance': 585,
#  'surveillance:type': 374,
#  'surveillance:zone': 300,
#  'survey:date': 4117,
#  'switch': 83,
#  'tactile_paving': 2714,
#  'takeaway': 381,
#  'taxi': 28,
#  'telecom': 70,
#  'telecom:medium': 24,
#  'to': 458,
#  'tobacco': 68,
#  'toilets': 51,
#  'toilets:wheelchair': 24,
#  'toll': 705,
#  'tourism': 1616,
#  'tower:type': 250,
#  'tracktype': 396,
#  'traffic_calming': 2653,
#  'traffic_sign': 264,
#  'traffic_signals': 284,
#  'traffic_signals:direction': 196,
#  'traffic_signals:sound': 30,
#  'traffic_signals:type': 20,
#  'trail_visibility': 44,
#  'trailblazed': 52,
#  'train': 108,
#  'tram': 206,
#  'transformer': 188,
#  'tunnel': 1712,
#  'turn:lanes': 656,
#  'turn:lanes:backward': 110,
#  'turn:lanes:forward': 129,
#  'type': 13015,
#  'type:FR:FINESS': 34,
#  'uic_ref': 111,
#  'unisex': 130,
#  'url': 937,
#  'usage': 558,
#  'vehicle': 25,
#  'vending': 288,
#  'vending_machine': 93,
#  'version': 20,
#  'via': 65,
#  'visibility': 32,
#  'voltage': 6347,
#  'voltage:primary': 200,
#  'voltage:secondary': 200,
#  'wall': 296783,
#  'was:amenity': 74,
#  'was:name': 511,
#  'was:shop': 247,
#  'waste': 34,
#  'water': 111,
#  'water_source': 280,
#  'waterway': 2042,
#  'website': 3470,
#  'wheelchair': 5085,
#  'wheelchair:description': 25,
#  'width': 317,
#  'wikidata': 1060,
#  'wikipedia': 639,
#  'wood': 41,
#  'zone:maxspeed': 1430}

# %%
phone = []
for event, elem in ET.iterparse('Compans_Caffarelli.osm', events=("start",)):
    if elem.tag == "node" or elem.tag == "way" or elem.tag == "relation": 
        for tag in elem.iter("tag"):
            key = tag.attrib['k']
            if (key == "phone") or (key == "contact:phone"):
                    phone.append(tag.attrib['v'])
pprint(len(phone))
# Out:
# 83

# %%
def audit_phonenumber(phonenumbers, actual_number):
    m = phone_number_re.search(actual_number)
    if not m:
        phonenumbers.append(actual_number)

def audit_phone(osmfile):
    osm_file = open(osmfile, "r")
    phonenumbers = []
    for event, elem in ET.iterparse(osm_file, events=("start",)):
            for tag in elem.iter():
                for key in tag.attrib:
                    if type(tag.attrib[key]) == str:
                        tag.attrib[key] = unicode(tag.attrib[key])
#                        print tag.attrib
                if elem.tag == "node" or elem.tag == "way":
                    for tag in elem.iter("tag"):
                        if (tag.attrib['k'] == "phone") or (tag.attrib['k'] == "contact:phone"):
                            audit_phonenumber(phonenumbers, tag.attrib['v'])
    osm_file.close()
    return phonenumbers

bad_phones = audit_phone('Compans_Caffarelli.osm')
pprint(bad_phones)
# Out:
# ['3631',
#  '3631',
#  '3631',
#  '3631',
#  '3631',
#  '3631',
#  '3631',
#  '3631',
#  '3631',
#  '3631',
#  '3631',
#  '3631',
#  '3631',
#  '3631',
#  u'3631',
#  u'3631',
#  u'3631',
#  u'3631',
#  u'3631',
#  u'3631',
#  '0984180201',
#  '0984180201',
#  '0984180201',
#  '0984180201',
#  '0984180201',
#  u'0984180201']

# %%
phone_number_re = re.compile(r'^\+')
m = phone_number_re.search('+33 5 62 15 01 70')
m.group()
# Out:
# '+'

# %% [markdown]
# The following __types_values()__ function ouputs a dictionary showing the values "v" attributes under alls tags named "tag" and how many times do they show up. As we can observe that the occurence of these are much lower with a higher variety and there are street names, websites, phone numbers and other useful information of each of the "tag" tags. The dictionary types_values_dict has all 'v' values sotred with the occurences and the dictionary that is shown below is values_slice_dict which shows the 'v' attributes that occur more than 100 times in the OpenStreetMap OSM XML file.

# %%
import phonenumbers

test_phone = '+33 5 61 62 02 26'
test_phone2 = '+33562256228'
x = phonenumbers.parse(test_phone, None)
y = phonenumbers.parse(test_phone2, None)
print x
print y
# Out:
# Country Code: 33 National Number: 561620226
# Country Code: 33 National Number: 562256228

# %%
def types_values(filename):
    types_values_dict = {}
    for event, element in ET.iterparse(filename, events=("start","end")):
        if event == "start":
            for tag in element.iter("tag"):
                value = tag.attrib['v']
                if value not in types_values_dict:
                    types_values_dict[value] = 1
                else:
                    types_values_dict[value] += 1
    return types_values_dict               
   

types_values_dict = types_values('Compans_Caffarelli.osm')
values_slice_dict = dict((k, v) for k, v in types_values_dict.items() if v >= 5)
pprint(values_slice_dict)
# Out:
# {'#572F08': 6,
#  '#58AC25': 6,
#  '#A0670F': 5,
#  '#DC006B': 5,
#  '#E675A7': 8,
#  '#FF671B': 6,
#  '#FFD900': 5,
#  '+33561215515': 6,
#  '+33562256228': 6,
#  '-1': 47,
#  '0': 14,
#  '0.15': 6,
#  '0.5': 41,
#  '1': 281,
#  u'1.5\u20ac': 63,
#  '10': 104,
#  '11': 94,
#  '11.5': 23,
#  '11B': 10,
#  '12': 106,
#  u'12\u20ac': 65,
#  '13': 76,
#  '14': 70,
#  '15': 89,
#  '16': 74,
#  '17': 82,
#  '17B': 6,
#  '18': 64,
#  '18 m': 10,
#  '19': 57,
#  '1997-08-13': 10,
#  '1B': 8,
#  '2': 209,
#  '2 hours': 63,
#  '2.5 hours': 65,
#  '20': 67,
#  '2007-11-16': 20,
#  '2011': 6,
#  '2011-06-11': 82,
#  '2011-11-06': 280,
#  '2012-04-04': 28,
#  '2012-05-30': 48,
#  '2012-10-04': 180,
#  '2012-11-29': 176,
#  '2012/10/04': 46,
#  '2015-02-14': 6,
#  '2015-03': 5,
#  '2015-04-06': 8,
#  '2018-09-08': 18,
#  '2018-09-29': 10,
#  '2018-11-06': 6,
#  '2018-11-11': 20,
#  '20B': 16,
#  '21': 52,
#  '22': 56,
#  '22B': 6,
#  '23': 38,
#  '23B': 6,
#  '24': 45,
#  '24 hours': 57,
#  '24/7': 12,
#  '25': 34,
#  '26': 38,
#  '27': 32,
#  '28': 41,
#  '29': 35,
#  '2B': 20,
#  '2T': 6,
#  '3': 213,
#  '30': 206,
#  '30B': 6,
#  '31': 34,
#  '31000': 804,
#  '32': 22,
#  '33': 30,
#  '34': 24,
#  '35': 22,
#  '36': 18,
#  '37': 18,
#  '38': 18,
#  '39': 18,
#  '3B': 10,
#  '4': 160,
#  '4.9': 7,
#  '40': 16,
#  '41': 18,
#  '42': 8,
#  '43': 18,
#  '44': 8,
#  '45': 26,
#  '46': 14,
#  '47': 14,
#  '48': 8,
#  '49': 6,
#  '4B': 6,
#  '5': 123,
#  '5.1': 8,
#  '5.3': 8,
#  '5.5': 8,
#  '50': 90,
#  '51': 6,
#  '52': 31,
#  '52.25': 15,
#  '52.75': 18,
#  '53': 24,
#  '54': 8,
#  '55': 10,
#  '56': 10,
#  '57': 8,
#  '58': 8,
#  '59': 8,
#  '5B': 8,
#  '6': 143,
#  '61': 6,
#  '62': 8,
#  '63': 9,
#  '6B': 12,
#  '7': 137,
#  '7.5': 6,
#  '7B': 6,
#  '8': 147,
#  '9': 104,
#  '9B': 6,
#  'A': 6,
#  u'All\xe9e Charles Denat': 7,
#  'Andana Charles Denat': 6,
#  'Arnaud Bernard': 11,
#  u'Avenue Honor\xe9 Serres': 68,
#  'Avenue Serres': 6,
#  'B': 11,
#  'BNP Paribas': 6,
#  "Baloard d'Estrasborg": 6,
#  'Banque Populaire': 6,
#  'Bing': 295,
#  'Borderouge': 7,
#  'Boulevard Armand Duportal': 63,
#  'Boulevard Duportal': 8,
#  'Boulevard Lascrosses': 176,
#  'Boulevard Leclerc': 10,
#  "Boulevard d'Arcole": 124,
#  'Boulevard de Strasbourg': 16,
#  u'Boulevard du Mar\xe9chal Leclerc': 12,
#  'C': 6,
#  'CIC': 10,
#  'CROUS Toulouse': 8,
#  u"Caisse d'\xc9pargne": 6,
#  u'Carri\xe8ra Jos\xe8p Merlin': 6,
#  u'Carri\xe8ra Las Cr\xf2sas': 8,
#  u'Carri\xe8ra Leonce Cast\xe8lbon': 6,
#  u'Carri\xe8ra Naut Bernat': 6,
#  u"Carri\xe8ra de l'Olm d'en Bartas": 5,
#  u'Carri\xe8ra dels Quistans de la Merc\xe9': 6,
#  u'Carri\xe8ra dels Tretze Vents': 6,
#  'Celtipharm - 10/2014': 6,
#  'Centre Commercial Reflets Compans': 12,
#  'Cheminement Henri Bosco': 6,
#  u'Cit\xe9 Administrative': 6,
#  'Compans Caffarelli': 42,
#  u'Conseil D\xe9partemental de Haute-Garonne': 6,
#  u'Cr\xe9dit Agricole': 8,
#  'D': 6,
#  u'Donn\xe9es Toulouse M\xe9tropole': 10,
#  'E': 6,
#  'Esplanade Compans Caffarelli': 46,
#  'F': 6,
#  'FR': 16,
#  'FR:30': 26,
#  'GPS': 6,
#  'Grand Rond': 7,
#  'GrandToulouse': 398,
#  u'H\xe9racl\xe8s': 8,
#  u'Impasse de S\xe9bastopol': 8,
#  'Indigo': 7,
#  'JCDecaux': 36,
#  'JOSM': 14,
#  u'Jean Jaur\xe8s': 6,
#  "Jeanne d'Arc": 13,
#  'KFC': 6,
#  'L1': 6,
#  'LCL': 8,
#  'LECLERC': 22,
#  'La Banque Postale': 8,
#  'La Poste': 16,
#  'Leclerc': 12,
#  'Ligne B': 5,
#  'Mairie de Toulouse': 6,
#  "McDonald's": 6,
#  'Minimes - Claude Nougaro': 5,
#  'Mo-Sa 09:00-20:00; PH off;Aug 1-Aug 15 off': 125,
#  'Mo-Sa 18:00-09:00; PH off;Aug 1-Aug 15 off': 6,
#  'Mo-Th 05:15-24:00; Fr-Sa 05:15-24:00, 00:00-01:00; Su 05:15-24:00': 5,
#  u'Ne pas d\xe9placer ce point, cf. - Do not move this node, see - http://wiki.openstreetmap.org/wiki/WikiProject_France/Rep\xe8res_G\xe9od\xe9siques#Permanence_des_rep.C3.A8res': 8,
#  'Nov-Jan 07:45-18:00; Feb 07:45-18:30; Mar 1-15 07:45-19:00; Mar 16-31 07:45-19:30;Apr 07:45-20:00;May 07:45-20:30;Jun-Aug 07:45-21:00;Sep 1-15 07:45-20:30; Sep 16-30 07:45-19:30;Oct 1-15 07:45-19:00;Oct 16-31 07:45-18:30': 17,
#  'PA31000011': 12,
#  'Picard': 6,
#  'Place Alfonse Jourdain': 20,
#  'Place Alphonse Jourdain': 14,
#  'Place Arnaud Bernard': 56,
#  'Place Ritay': 12,
#  'Place Saint-Julien': 22,
#  'Place Saint-Sernin': 33,
#  'Place des Tiercerettes': 6,
#  'Place du Peyrou': 18,
#  u'Pla\xe7a Naut Bernat': 6,
#  u'Pla\xe7a Sant Sernin': 6,
#  'Ramonville': 7,
#  u'Rempart m\xe9di\xe9val': 10,
#  u'Rempart m\xe9di\xe9val de Toulouse': 10,
#  'Rond-Point Gabriel Marty': 12,
#  'Rue Alaric II': 15,
#  'Rue Arnaud Bernard': 58,
#  'Rue Auber': 45,
#  'Rue Bellegarde': 10,
#  'Rue Castelbou': 6,
#  'Rue Danielle Casanova': 34,
#  u'Rue Escoussi\xe8res Arnaud Bernard': 30,
#  'Rue Francisque Sarcey': 6,
#  'Rue Gatien Arnoult': 50,
#  'Rue Gramat': 25,
#  u'Rue Henri B\xe9raldi': 6,
#  u'Rue Henri Douvill\xe9': 20,
#  'Rue Jean Rancy': 8,
#  'Rue Lancefoc': 88,
#  'Rue Lascrosses': 32,
#  'Rue Lejeune': 94,
#  u'Rue L\xe9once Castelbou': 60,
#  'Rue Merly': 48,
#  'Rue Pierre Laplace': 6,
#  'Rue Pierre Salies': 8,
#  'Rue Pouzonville': 36,
#  u'Rue P\xe9trarque': 20,
#  'Rue Ritay': 22,
#  'Rue Roode': 6,
#  'Rue Saint-Bernard': 18,
#  'Rue Saint-Charles': 53,
#  'Rue Saint-Germier': 31,
#  "Rue d'Artagnan": 8,
#  "Rue d'Embarthe": 72,
#  'Rue de Coulmiers': 6,
#  u'Rue de S\xe9bastopol': 28,
#  'Rue de Toul': 54,
#  "Rue de l'Hirondelle": 26,
#  'Rue de la Balance': 16,
#  'Rue de la Chaine': 10,
#  u'Rue de la Cha\xeene': 46,
#  u'Rue de la Cit\xe9 Administrative': 10,
#  'Rue de la Concorde': 5,
#  "Rue de la Verge d'Or": 17,
#  'Rue des Chalets': 72,
#  'Rue des Cuves Saint-Sernin': 14,
#  u'Rue des Puits Creus\xe9s': 28,
#  u'Rue des Qu\xeateurs': 49,
#  'Rue des Salenques': 91,
#  'Rue des Treize-Vents': 6,
#  'Rue des Trois Piliers': 42,
#  'Rue des Trois Renards': 24,
#  u'Rue du B\xe9arnais': 15,
#  "Rue du Canon d'Arcole": 41,
#  'Rue du Taur': 25,
#  u'Rue \xc9douard Dulaurier': 53,
#  u'Rue \xc9mile Cartailhac': 26,
#  u'R\xe9seau Arc-en-Ciel;Tiss\xe9o': 6,
#  u'R\xe9sidence A\xe9rophile': 6,
#  'SAINT-SERNIN': 11,
#  u'Soci\xe9t\xe9 G\xe9n\xe9rale': 6,
#  'TAUR': 6,
#  u'Tiss\xe9o': 135,
#  'Tolosa': 26,
#  'Tolosa-2': 15,
#  'Tolosa-3': 26,
#  'Toulouse': 798,
#  'Toulouse - Orthophotoplan 2011': 14,
#  u'Toulouse M\xe9tropole': 18,
#  'ToulouseMetropole': 493,
#  'ToulouseMetropole - Orthophotoplan 2013': 44,
#  'VALADE': 14,
#  u'V\xe9l\xf4Toulouse': 30,
#  'administrative': 16,
#  'apartments': 24,
#  'asphalt': 277,
#  'associatedStreet': 149,
#  'atm': 10,
#  'bakery': 16,
#  'bank': 24,
#  'bar': 18,
#  'basin': 12,
#  'beauty': 10,
#  'bench': 101,
#  'bicycle_parking': 42,
#  'bicycle_rental': 30,
#  'billboard': 26,
#  'bing': 8,
#  'bollard': 49,
#  'boundary': 13,
#  'brick': 153,
#  'broadleaved': 110,
#  'building_passage': 12,
#  'bump': 12,
#  'burger': 6,
#  'bus': 41,
#  'bus_stop': 36,
#  'butcher': 12,
#  u'cadastre-dgi-fr source : Direction G\xe9n\xe9rale des Imp\xf4ts - Cadastre ; mise \xe0 jour : 2008': 22,
#  u'cadastre-dgi-fr source : Direction G\xe9n\xe9rale des Imp\xf4ts - Cadastre ; mise \xe0 jour : 2012': 112,
#  u'cadastre-dgi-fr source : Direction G\xe9n\xe9rale des Imp\xf4ts - Cadastre ; mise \xe0 jour : 2013': 6,
#  u'cadastre-dgi-fr source : Direction G\xe9n\xe9rale des Imp\xf4ts - Cadastre. Mise \xe0 jour : 2009': 24,
#  u'cadastre-dgi-fr source : Direction G\xe9n\xe9rale des Imp\xf4ts - Cadastre. Mise \xe0 jour : 2010': 2181,
#  u'cadastre-dgi-fr source : Direction G\xe9n\xe9rale des Imp\xf4ts - Cadastre. Mise \xe0 jour : 2011': 2287,
#  u'cadastre-dgi-fr source : Direction G\xe9n\xe9rale des Imp\xf4ts - Cadastre. Mise \xe0 jour : 2012': 14,
#  u'cadastre-dgi-fr source : Direction G\xe9n\xe9rale des Imp\xf4ts - Cadastre. Mise \xe0 jour : 2013': 23,
#  u'cadastre-dgi-fr source : Direction G\xe9n\xe9rale des Imp\xf4ts - Cadastre. Mise \xe0 jour : 2014': 8,
#  'cafe': 32,
#  'camera': 6,
#  'canton': 21,
#  'catholic': 5,
#  'christian': 5,
#  'city_wall': 12,
#  'company': 8,
#  'concrete': 5,
#  'container': 34,
#  'convenience': 18,
#  'crossing': 288,
#  'crous-cuarsenal@ac-toulouse.fr': 6,
#  'cushion': 16,
#  'cylinder': 39,
#  u'data.gouv.fr:Minist\xe8re de la Culture - 04/2015': 13,
#  u'data.gouv.fr:\xc9ducation Nationale - 05/2016': 16,
#  'data.toulouse-metropole.fr': 16,
#  'defibrillator': 8,
#  'delivery': 29,
#  'designated': 23,
#  'destination': 66,
#  'diagonal': 8,
#  'down': 6,
#  'drinking_water': 8,
#  'driveway': 32,
#  'driving_school': 14,
#  'employment_agency': 8,
#  'estate_agent': 7,
#  'fast_food': 62,
#  'fence': 83,
#  'fire_hydrant': 60,
#  'fitness_centre': 6,
#  'flat': 73,
#  'footway': 203,
#  'forward': 14,
#  'fr_tisseo': 75,
#  'free': 63,
#  'french': 6,
#  'gabled': 16,
#  'gate': 112,
#  'give_way': 10,
#  'government': 18,
#  'grass': 39,
#  'green': 6,
#  'hairdresser': 24,
#  'hipped': 6,
#  'hotel': 12,
#  'http://data.grandtoulouse.fr': 30,
#  'http://geodesie.ign.fr/fiches/index.php?module=e&action=fichepdf&source=carte&sit_no=3155504': 10,
#  'http://storage9.openstreetcam.org/files/photo/2018/9/8/lth/1287725_0_2e3e5_16.jpg': 8,
#  'http://www.crous-toulouse.fr/1-35482-Fiche-detaillee.php?id=31': 6,
#  'http://www.gegeloccitan-photo.com/article-rue-des-queteurs-toulouse-le-bourg-108707861.html': 6,
#  'http://www.legifrance.gouv.fr/affichTexte.do?cidTexte=JORFTEXT000028621951': 5,
#  'insurance': 6,
#  'kebab': 12,
#  'kindergarten': 12,
#  'knowledge': 6,
#  'lane': 60,
#  'laundry': 6,
#  'library': 6,
#  'lift_gate': 12,
#  'limited': 6,
#  'living_street': 41,
#  'local_knowledge': 38,
#  u'lyc\xe9e': 6,
#  'main': 60,
#  'marked': 28,
#  'mhs': 22,
#  'moroccan': 6,
#  'motorcycle_parking': 11,
#  'multi': 8,
#  'multipolygon': 135,
#  'newsagent': 6,
#  'no': 585,
#  'no_left_turn': 8,
#  'no_parking': 104,
#  'no_u_turn': 6,
#  'none': 34,
#  'on_street': 62,
#  'only': 6,
#  'opposite': 126,
#  'opposite_lane': 8,
#  'outside': 6,
#  'overground': 10,
#  'parallel': 53,
#  'parking': 69,
#  'parking_aisle': 95,
#  'parking_entrance': 7,
#  'parking_space': 14,
#  'parking_tickets': 10,
#  'path': 6,
#  'paved': 55,
#  'pedestrian': 82,
#  'permissive': 6,
#  'pharmacy': 10,
#  'pillar': 64,
#  'pitch': 6,
#  'pizza': 16,
#  'place_of_worship': 5,
#  'platform': 34,
#  'playground': 6,
#  'political': 22,
#  'post_box': 10,
#  'poster_box': 30,
#  'primaire': 6,
#  'primary': 62,
#  'private': 106,
#  'pub': 16,
#  'public': 26,
#  'public_transport': 47,
#  'pyramidal': 31,
#  'recycling': 34,
#  'red': 48,
#  'regional': 12,
#  'residential': 160,
#  'residents': 64,
#  'restaurant': 72,
#  'restriction': 18,
#  'rising': 6,
#  'roof_tiles': 47,
#  'roundabout': 16,
#  'route': 30,
#  'route_master': 17,
#  'sandwich': 18,
#  'school': 25,
#  'secondary': 8,
#  'service': 204,
#  'sett': 6,
#  'share_busway': 40,
#  'sidewalk': 50,
#  'signal': 6,
#  'skillion': 10,
#  'social_facility': 12,
#  'stands': 18,
#  'station': 42,
#  'steps': 36,
#  'stop_area': 45,
#  'stop_position': 64,
#  'street_lamp': 8,
#  'subway': 49,
#  'subway_entrance': 10,
#  'surface': 16,
#  'surveillance': 52,
#  'survey': 234,
#  'survey2013': 6,
#  'survey_point': 8,
#  'swimming_pool': 16,
#  'table': 8,
#  'tertiary': 20,
#  'theatre': 6,
#  'ticket': 130,
#  'toilets': 16,
#  'traffic_signals': 101,
#  'tree': 289,
#  'tree_row': 92,
#  'uncontrolled': 126,
#  'underground': 13,
#  'university': 8,
#  'up': 18,
#  'vacant': 6,
#  'vending_machine': 10,
#  'veranda': 10,
#  u'v\xe9randa': 10,
#  'wall': 196,
#  'waste_basket': 54,
#  'wlan': 6,
#  'yes': 4727,
#  'zebra': 168,
#  u'\xa9IGN 2010 dans le cadre de la cartographie r\xe9glementaire': 10,
#  u'\u0422\u0443\u043b\u0443\u0437\u0430': 14,
#  u'\u0422\u0443\u043b\u0443\u0437\u0430-2': 9,
#  u'\u0422\u0443\u043b\u0443\u0437\u0430-3': 14,
#  u'\u062a\u0648\u0644\u0648\u0632': 10,
#  u'\u062a\u0648\u0644\u0648\u0632-2': 6,
#  u'\u062a\u0648\u0644\u0648\u0632-3': 10}

# %% [markdown]
# Both keys and values shown above are the attributes that we need to clean up before converting to the JSON file. This is the information fed by humans wihch has the most errors in syntax and formats clearly. The rest of the attributes found directly under the elements such as "lat", "lon", "id", etc have all the same format and there are the same number of elements so they are clean enough to input them into the JSON file and then into the MongoDB database.

# %% [markdown]
# In this project we will just clean up some data for the 'k' and 'v' attributes however before showing in the next section the plan that has been developed to clean the data, we do some more auditing to understand a bit better these attributes and to try and cluster the syntax errors that we find in these to help us develop the plan to clean the data.

# %% [markdown]
# The following function __key_types()__ looks through all tags called "tag" and puts the 'k' attribute into the following different categories and the occurences of them:
# - "lowercase", for tags that contain only lowercase letters and are valid,
# - "lowercase_colon", for otherwise valid tags with a colon in their names,
# - "lowercase_semicolon", for otherwise valid tags with a semicolon in their names,
# - "lowercase_morethanone_colon", for tags with at least two semicolons in their names,
# - "capitalized", for tags starting with a capital letter,
# - "problemchars", for tags with problematic characters, and
# - "other", for other tags that do not fall into the other three categories.

# %%
lowercase = re.compile(r'^([a-z]|_)*$')
lowercase_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
lowercase_semicolon = re.compile(r'^([a-z]|_)*;([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')
capitalized = re.compile(r'^([A-Z])\w')
lowercase_morethanone_colon = re.compile(r'(\b:\b)+')
     

def key_type(element, keys):
    if element.tag == "tag":
        if lowercase.search(element.attrib['k']):
            keys['lowercase'] += 1
#            print("k:" + element.attrib['k'] + " " "v:" + element.attrib['v'])
        elif lowercase_colon.search(element.attrib['k']):
            keys['lowercase_colon'] += 1
#            print("k:" + element.attrib['k'] + " " "v:" + element.attrib['v'])
        elif capitalized.search(element.attrib['k']):
            keys['capitalized'] += 1
        elif lowercase_morethanone_colon.search(element.attrib['k']):
            keys['lowercase_morethanone_colon'] += 1
#            print(element.attrib['k'])
        elif lowercase_semicolon.search(element.attrib['k']):
            keys['lowercase_semicolon'] += 1
        elif problemchars.search(element.attrib['k']):
            keys['problemchars'] += 1
        else:
            keys['other'] += 1
#            print(element.attrib['k'])

    return keys


def process_map_keys(filename):
    keys = {"lowercase": 0, "lowercase_colon": 0, "lowercase_morethanone_colon": 0,"lowercase_semicolon": 0, "capitalized": 0, "problemchars": 0, "other": 0}
    for _, element in ET.iterparse(filename):
        keys = key_type(element, keys)

    return keys


keys = process_map_keys('Toulouse.osm')
pprint(keys)
# Out:
# {'capitalized': 165,
#  'lowercase': 1432376,
#  'lowercase_colon': 202929,
#  'lowercase_morethanone_colon': 11856,
#  'lowercase_semicolon': 0,
#  'other': 24,
#  'problemchars': 0}

# %%
test_string = 'hola:buenas: com'
#lowercase_morethanone_colon = re.compile(r':{2,}')
lowercase_morethanone_colon = re.compile(r'(\b:\b)+')
print(lowercase_morethanone_colon.search(test_string))
# Out:
# <_sre.SRE_Match object at 0x0000000008FE4E40>

# %% [markdown]
# Since we say some 'v' attributes of the tag "tag" that had some special characters like \xe9, \xe8, \xe, etc we will also try and find how many of attributes contain special characters. The __value_types()__ function categorizes into categories with problem characters which is the first filter then 'v' atrributes with capital letters to begin and the rest are i the others categories. We can see that a big portion of the 'v' attributes have special characters.

# %%
problemchars_nospaces = re.compile(r'^(\\)')

def value_type(element, values):
    if element.tag == "tag":
        if problemchars_nospaces.search(element.attrib['v']):
            values['problemchars'] += 1
            print (element.attrib['v'])
        elif lowercase_colon.search(element.attrib['v']):
            values['lowercase_colon'] += 1
        elif lowercase_morethanone_colon.search(element.attrib['v']):
            values['lowercase_morethanone_colon'] += 1
        elif lowercase_semicolon.search(element.attrib['v']):
            values['lowercase_semicolon'] += 1
        elif capitalized.search(element.attrib['v']):
            values['capitalized'] += 1
        else:
            values['other'] += 1
#            print(element.attrib['v'])

    return values


def process_map_values(filename):
    values = {"capitalized": 0, "problemchars": 0, "other": 0, "lowercase_colon": 0, "lowercase_morethanone_colon": 0,"lowercase_semicolon": 0}
    for _, element in ET.iterparse(filename):
        values = value_type(element, values)

    return values

values = process_map_values('Compans_Caffarelli.osm')
pprint(values)
# Out:
# {'capitalized': 3272,
#  'lowercase_colon': 0,
#  'lowercase_morethanone_colon': 200,
#  'lowercase_semicolon': 4,
#  'other': 12789,
#  'problemchars': 0}

# %% [markdown]
# # Plan for Cleaning Data

# %% [markdown]
# The cleaning of the data will be performed for the inputs of the data where the human error is big. In these areas is where different users input data regarding the `k` and `v` attributes under the tag `tag`. The following things will be cleaned up:<br>
# 1) The street types will be all filled cleaned to look consistent and have capitalized the first letter of the word and have the complete word for it so there are no abbreviations, and look like the following examples "Rue", "Avenue, etc
# 2) The phone number attribute for each of the elements where we can find this attribute will be cleaned up to not have a spaces in the string and any brackets and just have the phone number with no space and starting with the international code so "0033".

# %% [markdown]
# # Cleaning Data

# %% [markdown]
# ## 1) Abbreviated, Misspelled and Lower Case Street Types

# %% [markdown]
# The names of the street types e.g. rue, avenue, etc were changed to all having the first letter capitalized and non abbreviated types. E.g. rue => Rue, Av. => Avenue, Bd => Boulevard

# %%
street_type_re = re.compile(r'^\b\S+\.?', re.IGNORECASE)

expected_street_ascii = ["Rue", "Esplanade", "Boulevard", "Avenue", "Place", u'All\xe9e', 'Route', 'Voie', 
                   'Impasse', 'Chemin', 'Rond-Point', 'Quai', 'Promenade', 'Port', 'Passage', 'Mail',
                   'Descente', 'Clos' ]

expected_street = map(unicode,expected_street_ascii)
# UPDATE THIS VARIABLE
mapping_street = { u"route": u"Route",
            u"rue": u"Rue",
            u"rte": u"Route",
            u"esplanade": u"Esplanade",
            u"voie":u"Voie",
            u"place":u"Place",
            u"impasse":u"Impasse",
            u"chemin":u"Chemin",
            u"boulevard":u"Boulevard",
            u"avenue":u"Avenue",
            u'all\xe9es': u'All\xe9e',
            u'all\xe9e': u'All\xe9e',
            u"RUE":u"Rue",
            u"ROUTE":u"Route",
            u"Cheminement":u"Chemin",
            u"Av.":u"Avenue",
            u"Bd":u"Boulevard",
            u'All\xe9es': u'All\xe9e',
            u"AVENUE":u"Avenue",
            u"ALLEE": u'All\xe9e'
            }

def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected_street:
            street_types[street_type].add(street_name)
            
def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")

def audit_street(osmfile):  
    osm_file = open(osmfile, "r")
    street_types = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):
            for tag in elem.iter():
                for key in tag.attrib:
                    if type(tag.attrib[key]) == str:
                        tag.attrib[key] = unicode(tag.attrib[key])
#                        print tag.attrib
#                        print type(tag.attrib[key])
                if elem.tag == "node" or elem.tag == "way":
                    for tag in elem.iter("tag"):
                        if is_street_name(tag):
                            audit_street_type(street_types, tag.attrib['v'])
    osm_file.close()
    return street_types

# %% [markdown]
# Following the __update_name_street()__ function is defined which checks whether street type is in the expected_street list defined above and if not, it changes it via the mapping_street dictionary also defined above.

# %%
def update_name_street(name, mapping_street):

    m = street_type_re.search(name)
    street_type = m.group()
    if m and street_type in mapping_street:
#        print 'street_type', street_type
        if street_type not in expected_street:
            name = re.sub(street_type_re, mapping_street[street_type], name)

    return name

# %% [markdown]
# Finally the better name (cleaned up one) is shown versus how it looked before. In the full file all the keys found in mapping street dictionary are changed to the corresponsing cleaned up names. But below just one example is shown.

# %%
st_types = audit_street('Compans_Caffarelli.osm')
for st_type, ways in st_types.iteritems():
    for name in ways:
        better_name = update_name_street(name, mapping_street)
        print name, "=>", better_name
# Out:
# esplanade compans-caffarelli => Esplanade compans-caffarelli

# %% [markdown]
# ## 2) Phone number Inconsistent Format

# %% [markdown]
# Some phone number have the format as +33561

# %% [markdown]
# The following two functions take the list of phone numbers found under the `tags`, `node` and `way`, which are specifically found under the attributed "contact:phone" and "phone" and put them into two baskets, one being the ones starting with a plus sign and the other the ones that are not starting with a plus sign.

# %%
phone_number_re = re.compile(r'\+.')
phone_number_cleaning_re = re.compile(r'^\+[0-9]*')

def audit_phonenumber(no_plus_sign_phones, plus_sign_phones, actual_number):
    m = phone_number_re.search(actual_number)
    if m:
        plus_sign_phones.append(actual_number)        
    if not m:
        no_plus_sign_phones.append(actual_number)
        
def audit_phone(osmfile):
    osm_file = open(osmfile, "r")
    no_plus_sign_phones = []
    plus_sign_phones = []
    for event, elem in ET.iterparse(osm_file, events=("start",)):
        for tag in elem.iter():
            for key in tag.attrib:
                if type(tag.attrib[key]) == str:
                    tag.attrib[key] = unicode(tag.attrib[key])
        if elem.tag == "node" or elem.tag == "way" or elem.tag == "relation":
            for tag in elem.iter("tag"):
                if (tag.attrib['k'] == "phone") or (tag.attrib['k'] == "contact:phone"):
                    audit_phonenumber(no_plus_sign_phones, plus_sign_phones, actual_number=tag.attrib['v'])
    osm_file.close()
    return no_plus_sign_phones, plus_sign_phones

# %% [markdown]
# Next, for this small sample file we can see what we find in the non plus sign phones, there are phone numbers that either start with "0" which means that these are the phones how the are dialed locally so to keep it consistent the "0" is subistituted for "0033".
#
# The second type is a number that is "3631". This number is specific to the French reagion as a short number to call the post office. The full number is "0033972721213" so it is subistited. And finally some other phones in the full file there are some numbers that start with "33" so for these a "00 is added before so that the number starts like "0033"

# %%
no_plus_sign_phones, plus_sign_phones = audit_phone('Compans_Caffarelli.osm')
pprint(no_plus_sign_phones)
# Out:
# [u'3631', u'0984180201']

# %% [markdown]
# For the numbers that start with a plus sign we can have just replaced the "+" by "00".

# %%
pprint(plus_sign_phones)
# Out:
# [u'+33 5 61 63 81 82',
#  u'+33562309977',
#  u'+33561216654',
#  u'+33 5 61 62 02 26',
#  u'+33 5 61 22 18 88',
#  u'+33 5 61 21 68 81',
#  u'+33 5 61 21 74 74',
#  u'+33561213764',
#  u'+33 9 54 13 39 50',
#  u'+33561215533',
#  u'+33 5 61 21 76 74',
#  u'+33 5 61 12 67 01',
#  u'+33 5 34 30 92 51',
#  u'+33 534251010',
#  u'+33 5 34 33 51 42',
#  u'+33 5 62 80 57 01',
#  u'+33 5 61 23 93 98',
#  u'+33 5 61 21 39 46',
#  u'+33 5 61 21 34 45',
#  u'+33 5 61 21 30 75',
#  u'+33561221465',
#  u'+33561218070',
#  u'+33561235686',
#  u'+33 5 61 23 16 22',
#  u'+33 5 62 30 05 30',
#  u'+33 5 34 25 28 82',
#  u'+33 5 34 25 28 82',
#  u'+33561217308',
#  u'+33561216184',
#  u'+33561219633',
#  u'+33561218738',
#  u'+33 5 61 23 57 51',
#  u'+33 5 61 22 47 60',
#  u'+33 5 61 62 24 49',
#  u'+33 5 31 22 03 14',
#  u'+33 5 61 21 78 27',
#  u'+33 5 61 29 23 49',
#  u'+33 5 61 12 12 72',
#  u'+33561230137',
#  u'+33 5 61 23 82 52',
#  u'+33 5 61 23 77 28',
#  u'+33 5 61 22 17 77',
#  u'+33 5 34 33 77 32',
#  u'+33 9 88 77 66 80',
#  u'+33 6 30 13 30 72',
#  u'+33 5 61 21 74 89',
#  u'+33 5 61 21 54 31',
#  u'+33561102030',
#  u'+33 5 61 21 04 42',
#  u'+33 5 61 23 98 98',
#  u'+33 5 61 47 81 37',
#  u'+33 5 61 22 53 77',
#  u'+33 5 61 21 15 52',
#  u'+33 5 61 21 82 72',
#  u'+33562800494',
#  u'+33 5 61 54 14 55',
#  u'+33 5 61 22 96 09',
#  u'+33 9 72 46 91 61',
#  u'+33 5 81 34 37 18',
#  u'+33534254740',
#  u'+33 5 34 44 63 40',
#  u'+33 5 61 22 51 42',
#  u'+33 6 83 45 01 01',
#  u'+33 5 61 23 92 07',
#  u'+33 5 61 21 30 00',
#  u'+33561234140',
#  u'+33 6 71 38 21 21',
#  u'+33 5 61 62 74 55',
#  u'+33 5 61 13 96 22',
#  u'+33 5 61 12 16 37',
#  u'+33 5 61 23 08 09',
#  u'+33 5 61 23 05 43',
#  u'+33561221300',
#  u'+33 5 34 24 02 82',
#  u'+33 5 62 27 22 30',
#  u'+33 5 62 30 21 80',
#  u'+33 5 61 22 34 32',
#  u'+33562256228',
#  u'+33562256228',
#  u'+33562256228',
#  u'+33 5 61 41 70 70']

# %% [markdown]
# Finally apart from the replacing of numbers and plus signs mentioned below, all the spaces and brackets are removed to have a consistent 12 digit phone numbers.

# %%
for plus_sign_phone in plus_sign_phones:
    m = phone_number_cleaning_re.search(plus_sign_phone)
    if m:
        updated_number_step1 = re.sub(r'^\+','00',plus_sign_phone)
        updated_number = re.sub(r'[\D|\s]+','',updated_number_step1)            
        print plus_sign_phone,"=>", updated_number

for no_plus_sign_phone in no_plus_sign_phones:
    if no_plus_sign_phone == u'3631':
        updated_number = u'0033972721213'
        print no_plus_sign_phone,"=>", updated_number
    else:
        phone_number_start_0_re = re.compile(r'^[0]')
        phone_number_start_0_re = re.compile(r'^[0]')
        match_phone = phone_number_start_0_re.match(no_plus_sign_phone)
        match_phone = phone_number_start_0_re.match(no_plus_sign_phone)
        if match_phone:
            updated_number_step1 = re.sub(r'^[0]','0033',no_plus_sign_phone)
            updated_number = re.sub(r'[\D|\s]+','',updated_number_step1)
            print no_plus_sign_phone,"=>", updated_number
        else:
            updated_number_step1 = re.sub(r'^[3]','003',no_plus_sign_phone)
            updated_number = re.sub(r'[\D|\s]+','',updated_number_step1)
            print no_plus_sign_phone,"=>", updated_number
# Out:
# +33 5 61 63 81 82 => 0033561638182
# +33562309977 => 0033562309977
# +33561216654 => 0033561216654
# +33 5 61 62 02 26 => 0033561620226
# +33 5 61 22 18 88 => 0033561221888
# +33 5 61 21 68 81 => 0033561216881
# +33 5 61 21 74 74 => 0033561217474
# +33561213764 => 0033561213764
# +33 9 54 13 39 50 => 0033954133950
# +33561215533 => 0033561215533
# +33 5 61 21 76 74 => 0033561217674
# +33 5 61 12 67 01 => 0033561126701
# +33 5 34 30 92 51 => 0033534309251
# +33 534251010 => 0033534251010
# +33 5 34 33 51 42 => 0033534335142
# +33 5 62 80 57 01 => 0033562805701
# +33 5 61 23 93 98 => 0033561239398
# +33 5 61 21 39 46 => 0033561213946
# +33 5 61 21 34 45 => 0033561213445
# +33 5 61 21 30 75 => 0033561213075
# +33561221465 => 0033561221465
# +33561218070 => 0033561218070
# +33561235686 => 0033561235686
# +33 5 61 23 16 22 => 0033561231622
# +33 5 62 30 05 30 => 0033562300530
# +33 5 34 25 28 82 => 0033534252882
# +33 5 34 25 28 82 => 0033534252882
# +33561217308 => 0033561217308
# +33561216184 => 0033561216184
# +33561219633 => 0033561219633
# +33561218738 => 0033561218738
# +33 5 61 23 57 51 => 0033561235751
# +33 5 61 22 47 60 => 0033561224760
# +33 5 61 62 24 49 => 0033561622449
# +33 5 31 22 03 14 => 0033531220314
# +33 5 61 21 78 27 => 0033561217827
# +33 5 61 29 23 49 => 0033561292349
# +33 5 61 12 12 72 => 0033561121272
# +33561230137 => 0033561230137
# +33 5 61 23 82 52 => 0033561238252
# +33 5 61 23 77 28 => 0033561237728
# +33 5 61 22 17 77 => 0033561221777
# +33 5 34 33 77 32 => 0033534337732
# +33 9 88 77 66 80 => 0033988776680
# +33 6 30 13 30 72 => 0033630133072
# +33 5 61 21 74 89 => 0033561217489
# +33 5 61 21 54 31 => 0033561215431
# +33561102030 => 0033561102030
# +33 5 61 21 04 42 => 0033561210442
# +33 5 61 23 98 98 => 0033561239898
# +33 5 61 47 81 37 => 0033561478137
# +33 5 61 22 53 77 => 0033561225377
# +33 5 61 21 15 52 => 0033561211552
# +33 5 61 21 82 72 => 0033561218272
# +33562800494 => 0033562800494
# +33 5 61 54 14 55 => 0033561541455
# +33 5 61 22 96 09 => 0033561229609
# +33 9 72 46 91 61 => 0033972469161
# +33 5 81 34 37 18 => 0033581343718
# +33534254740 => 0033534254740
# +33 5 34 44 63 40 => 0033534446340
# +33 5 61 22 51 42 => 0033561225142
# +33 6 83 45 01 01 => 0033683450101
# +33 5 61 23 92 07 => 0033561239207
# +33 5 61 21 30 00 => 0033561213000
# +33561234140 => 0033561234140
# +33 6 71 38 21 21 => 0033671382121
# +33 5 61 62 74 55 => 0033561627455
# +33 5 61 13 96 22 => 0033561139622
# +33 5 61 12 16 37 => 0033561121637
# +33 5 61 23 08 09 => 0033561230809
# +33 5 61 23 05 43 => 0033561230543
# +33561221300 => 0033561221300
# +33 5 34 24 02 82 => 0033534240282
# +33 5 62 27 22 30 => 0033562272230
# +33 5 62 30 21 80 => 0033562302180
# +33 5 61 22 34 32 => 0033561223432
# +33562256228 => 0033562256228
# +33562256228 => 0033562256228
# +33562256228 => 0033562256228
# +33 5 61 41 70 70 => 0033561417070
# 3631 => 0033972721213
# 0984180201 => 0033984180201

# %% [markdown]
# ## Converting all nodes to JSON format

# %% [markdown]
# As mentioned at the beginning, now the OSM XML file will be converted to the following format with the relative cleaned up street types and phone numbers:
#
# The format in which we want to convert the OSM XML file is the following:
#
# ```
# {
# "id": "2406124091",
# "type: "node",
# "visible":"true",
# "created": {
#           "version":"2",
#           "changeset":"17206049",
#           "timestamp":"2013-08-03T16:43:42Z",
#           "user":"linuxUser16",
#           "uid":"1219059"
#         },
# "pos": [41.9757030, -87.6921867],
# "address": {
#           "housenumber": "5157",
#           "postcode": "60625",
#           "street": "North Lincoln Ave"
#         },
# "amenity": "restaurant",
# "cuisine": "mexican",
# "name": "La Cabana De Don Luis",
# "phone": "1 (773)-271-5176"
# }
# ```
